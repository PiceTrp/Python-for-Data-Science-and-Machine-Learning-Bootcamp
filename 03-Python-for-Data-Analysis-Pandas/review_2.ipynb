# %%
import numpy as np
import pandas as pd

# %%
np.random.randn(10,10)
# Out:
# array([[ 0.16886285, -2.1136567 ,  1.21858012,  0.3286886 , -0.11850335,
#          1.14808831, -0.52110509,  0.78367609, -0.7096626 , -0.11681224],
#        [ 0.86272313,  0.06345416, -1.25113096,  0.91199142, -0.30274313,
#          0.72393266, -0.46804003, -0.09979421, -0.78853243,  1.43577673],
#        [ 0.1793407 , -0.31721201,  0.52738107,  0.3866525 , -0.44490525,
#          1.44735535,  1.33254673, -1.04523372, -0.21115767, -0.14738171],
#        [-0.25320481,  1.16871435,  0.87926501,  1.23509833, -0.65914502,
#          0.69173308, -0.07575961, -1.46232068,  1.24710434,  1.20964012],
#        [ 1.14630825,  0.37887407, -0.33534342, -0.43128984, -0.86676139,
#          0.84588757,  0.48117172,  0.76918494, -0.62045318, -0.02462045],
#        [-0.93640601,  0.26584863,  0.45592086,  0.8080107 , -1.61077127,
#          0.06947126,  1.38724193,  1.53055866, -0.04611668,  0.49356966],
#        [ 0.56690426, -2.83850717,  0.92747223,  0.43471005, -2.21611334,
# ...
