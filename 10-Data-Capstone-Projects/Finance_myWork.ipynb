# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import os
# %matplotlib inline

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %% [markdown]
# <hr style='border:0.75px solid black'></hr>

# %%
os.environ['IEX_SANDBOX'] = 'enable'
os.environ["IEX_API_KEY"] = 'Tpk_a4768615ef3f4ae09ea874857d96a977'

# %%
# Bank of America
BAC = data.DataReader("BAC", 'iex', start, end)

# CitiGroup
C = data.DataReader("C", 'iex', start, end)

# Goldman Sachs
GS = data.DataReader("GS", 'iex', start, end)

# JPMorgan Chase
JPM = data.DataReader("JPM", 'iex', start, end)

# Morgan Stanley
MS = data.DataReader("MS", 'iex', start, end)

# Wells Fargo
WFC = data.DataReader("WFC", 'iex', start, end)

# %%
#the stocks information of Bank of America
BAC #Volume is just the actual volume how many stocks are traded on that day
# Out:
#              open   high    low  close    volume
# date
# 2006-12-29  54.59  54.39  53.46  55.51   7829836
# 2007-01-03  54.50  55.54  53.02  53.34  16556309
# 2007-01-04  53.62  54.97  54.77  56.24  13844550
# 2007-01-05  54.54  55.64  54.19  54.52  10713764
# 2007-01-08  54.77  55.62  54.50  55.03   9860371
# ...           ...    ...    ...    ...       ...
# 2015-12-24  17.90  17.53  17.32  17.36  29608418
# 2015-12-28  18.01  17.28  17.40  17.86  41942328
# 2015-12-29  17.80  18.21  17.79  18.08  46185664
# 2015-12-30  17.60  17.87  17.53  17.39  36181683
# 2015-12-31  17.42  17.42  17.08  17.57  48491489
#
# [2275 rows x 5 columns]

# %%
C
# Out:
#                open     high      low    close        volume
# date
# 2006-12-29  5858.00  5754.00  5582.00  5837.00  1.126846e+05
# 2007-01-03  5607.00  5696.00  5639.00  5793.00  2.311607e+05
# 2007-01-04  5761.00  5869.00  5498.00  5746.00  1.675669e+05
# 2007-01-05  5725.00  5683.00  5632.00  5634.00  1.356433e+05
# 2007-01-08  5473.00  5776.00  5564.00  5724.00  1.256227e+05
# ...             ...      ...      ...      ...           ...
# 2015-12-24    54.71    53.61    54.47    53.94  4.847261e+06
# 2015-12-28    53.57    52.61    52.90    53.85  8.871344e+06
# 2015-12-29    53.65    55.87    54.80    55.55  1.046104e+07
# 2015-12-30    55.44    53.33    52.46    54.90  8.911501e+06
# 2015-12-31    53.01    53.24    54.19    53.10  1.166603e+07
#
# [2275 rows x 5 columns]

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC], keys=tickers, axis=1)

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks #multilevel index on the columns : axis=1
# Out:
# Bank Ticker    BAC                                         C           \
# Stock Info    open   high    low  close      volume     open     high
# 2006-12-29   54.59  54.39  53.46  55.51   7829836.0  5858.00  5754.00
# 2007-01-03   54.50  55.54  53.02  53.34  16556309.0  5607.00  5696.00
# 2007-01-04   53.62  54.97  54.77  56.24  13844550.0  5761.00  5869.00
# 2007-01-05   54.54  55.64  54.19  54.52  10713764.0  5725.00  5683.00
# 2007-01-08   54.77  55.62  54.50  55.03   9860371.0  5473.00  5776.00
# ...            ...    ...    ...    ...         ...      ...      ...
# 2015-12-31   17.42  17.42  17.08  17.57  48491489.0    53.01    53.24
# 2014-08-13     NaN    NaN    NaN    NaN         NaN      NaN      NaN
# 2014-08-19     NaN    NaN    NaN    NaN         NaN      NaN      NaN
# 2014-08-21     NaN    NaN    NaN    NaN         NaN      NaN      NaN
# 2014-11-27     NaN    NaN    NaN    NaN         NaN      NaN      NaN
#
# ...

# %% [markdown]
# <hr style='border:0.75px solid black'></hr>

# %% [markdown]
#  ** From the bank_stocks information aboves, it is in Sand-box mode in IEX API that I've registered for free, but this information won't give the real and respective stocks from each banks: it's all scrambled. In order to use real information for the production usage, I have to register in the premium plan, which costs monthly. As the course provided the file that have real stocks information, I will use that instead. Just to remind myself that if I want to do some stuff in a financial purpose like this times, stocks, it would be great using IEX API. **

# %%
bank_stocks = pd.read_pickle('all_banks')

# %%
bank_stocks
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
bank_stocks.xs(key='Close',level=1,axis=1).max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
for tick in tickers:
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.9
# C 564.1
# GS 247.92
# JPM 70.08
# MS 89.3
# WFC 58.52

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
#It's like calculating the price percentage over yesterday's time.
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data=returns)
plt.tight_layout()

# %% [markdown]
# ___
# * just deal with the problem from the last bank_stocks *

# %% [markdown]
# #### Change the index to be datetime object and named 'Date'

# %%
returns['Date'] = pd.to_datetime(returns['index'])
returns
# Out:
#            index  BAC Return  C Return  GS Return  JPM Return  MS Return  \
# 0     2006-12-29         NaN       NaN        NaN         NaN        NaN
# 1     2007-01-03    0.022590 -0.008185   0.001059    0.013765   0.021808
# 2     2007-01-04   -0.007004  0.015608  -0.034780    0.009385   0.001948
# 3     2007-01-05   -0.009586 -0.001413   0.017742   -0.027102  -0.007391
# 4     2007-01-08   -0.016983 -0.016982   0.033838   -0.010167   0.004966
# ...          ...         ...       ...        ...         ...        ...
# 2274  2015-12-31    0.002841  0.015690   0.015408   -0.053783  -0.045808
# 2275  2014-08-13    0.000000  0.000000  -0.042221   -0.103855   0.023533
# 2276  2014-08-19    0.000000  0.000000  -0.030463   -0.022099   0.030963
# 2277  2014-08-21    0.000000  0.000000   0.048334    0.009143   0.005055
# 2278  2014-11-27    0.000000  0.000000   0.062076    0.054530   0.066272
#
#       WFC Return       Date
# 0            NaN 2006-12-29
# 1       0.046940 2007-01-03
# ...

# %%
returns.set_index('Date',inplace=True)

# %%
returns.drop('index',axis=1,inplace=True)

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-12-29         NaN       NaN        NaN         NaN        NaN         NaN
# 2007-01-03    0.022590 -0.008185   0.001059    0.013765   0.021808    0.046940
# 2007-01-04   -0.007004  0.015608  -0.034780    0.009385   0.001948    0.000801
# 2007-01-05   -0.009586 -0.001413   0.017742   -0.027102  -0.007391   -0.008000
# 2007-01-08   -0.016983 -0.016982   0.033838   -0.010167   0.004966   -0.010753

# %% [markdown]
# <hr style='border:0.75px solid black'></hr>

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
for i in tickers:
    print(returns[i + ' Return'][returns[i + ' Return']== returns[i+' Return'].min()])
# Out:
# Date
# 2009-01-20   -0.289694
# Name: BAC Return, dtype: float64
# Date
# 2011-05-06   -0.899107
# Name: C Return, dtype: float64
# Date
# 2009-01-20   -0.189596
# Name: GS Return, dtype: float64
# Date
# 2009-01-20   -0.207274
# Name: JPM Return, dtype: float64
# Date
# 2008-10-09   -0.258929
# Name: MS Return, dtype: float64
# Date
# 2009-01-20   -0.238223
# Name: WFC Return, dtype: float64

# %%
returns.idxmin() #notice that 4 of the banks have the same day for the worst drop
# Worst Drop (4 of them on Inauguration day)
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.min()
# Out:
# BAC Return   -0.289694
# C Return     -0.899107
# GS Return    -0.189596
# JPM Return   -0.207274
# MS Return    -0.258929
# WFC Return   -0.238223
# dtype: float64

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %%
returns.idxmax()
# Best Single Day Gain
# citigroup stock split in May 2011, but also JPM day after inauguration.
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.max()
# Out:
# BAC Return    0.352691
# C Return      8.769912
# GS Return     0.264678
# JPM Return    0.250967
# MS Return     0.869835
# WFC Return    0.327645
# dtype: float64

# %%
returns[returns['C Return'] == returns['C Return'].min()]
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2011-05-06    0.000813 -0.899107  -0.002061   -0.002878   0.003978    0.004266

# %%
returns[returns['C Return'] == returns['C Return'].max()]
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2011-05-09   -0.010561  8.769912  -0.006529   -0.001776  -0.006339   -0.001416

# %% [markdown]
# ## Real life events can affect stock prices

# %% [markdown]
# <hr style='border:0.75px solid black'></hr>

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %% [markdown]
# #### If the bank has a very large standard deviation of the returns, it means its stock is going up and down a lot

# %%
returns.std() #entire time period

# CItigroups has the riskiest stock prices since it had a huge crash
# If something such as a business crashes, it suddenly fails or becomes unsuccessful
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns[returns.index.year == 2015]
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2015-01-02    0.000559  0.002772   0.002992   -0.001438  -0.002320   -0.002189
# 2015-01-05   -0.029050 -0.031515  -0.031223   -0.031045  -0.031258   -0.027422
# 2015-01-06   -0.029919 -0.035205  -0.020229   -0.025929  -0.028800   -0.020865
# 2015-01-07    0.004745  0.009270   0.014903    0.001526   0.014278    0.005951
# 2015-01-08    0.020661  0.015048   0.015965    0.022346   0.014889    0.022137
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %%
returns[returns.index.year == 2015].std()
# they actually have a very similar risk profile
# the riskiest is MS
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# <hr style='border:0.75px solid black'></hr>

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
returns[returns.index.year == 2015].head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2015-01-02    0.000559  0.002772   0.002992   -0.001438  -0.002320   -0.002189
# 2015-01-05   -0.029050 -0.031515  -0.031223   -0.031045  -0.031258   -0.027422
# 2015-01-06   -0.029919 -0.035205  -0.020229   -0.025929  -0.028800   -0.020865
# 2015-01-07    0.004745  0.009270   0.014903    0.001526   0.014278    0.005951
# 2015-01-08    0.020661  0.015048   0.015965    0.022346   0.014889    0.022137

# %%
data = returns[returns.index.year == 2015]['MS Return']
data
# Out:
# Date
# 2015-01-02   -0.002320
# 2015-01-05   -0.031258
# 2015-01-06   -0.028800
# 2015-01-07    0.014278
# 2015-01-08    0.014889
#                 ...
# 2015-12-24   -0.003681
# 2015-12-28   -0.009544
# 2015-12-29    0.011812
# 2015-12-30   -0.009831
# 2015-12-31   -0.013031
# Name: MS Return, Length: 252, dtype: float64

# %%
sns.distplot(data,bins=100,color='g')

#here we can see that the distribution of this stock prices is pretty stable
#looking at percent returns that only diviate about 0.06 from the average

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns[returns.index.year == 2008]['C Return'], bins=100,color='purple')
# the std is quite a bit more stretched out: almost that 0.6
#10 times deviate over the distribution of the MS bank in 2015

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
bank_stocks.xs(key='Close',level=1,axis=1).plot.line(figsize=(15,8))

# %%
for i in tickers:
    bank_stocks[i]['Close'].plot(figsize=(15,8),label=i)
plt.legend(title='Bank Tickers')

# %%
bank_stocks.xs(key='Close',level=1,axis=1).iplot()
# Out:
# <div>                            <div id="f14ad0d8-89ca-4794-9ede-399a66e9ce18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# <hr style='border:0.75px solid black'></hr>

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(15,5))
bank_stocks['BAC']['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 day Average')
bank_stocks['BAC']['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
bank_stocks.xs(key='Close',level=1,axis=1)
# Out:
# Bank Ticker    BAC       C      GS    JPM     MS    WFC
# Date
# 2006-01-03   47.08  492.90  128.87  40.19  58.31  31.90
# 2006-01-04   46.58  483.80  127.09  39.62  58.35  31.53
# 2006-01-05   46.64  486.20  127.04  39.74  58.51  31.50
# 2006-01-06   46.57  486.20  128.84  40.02  58.57  31.68
# 2006-01-09   46.60  483.90  130.39  40.67  59.19  31.68
# ...            ...     ...     ...    ...    ...    ...
# 2015-12-24   17.27   52.71  182.47  66.60  32.48  54.82
# 2015-12-28   17.13   52.38  181.62  66.38  32.17  54.68
# 2015-12-29   17.28   52.98  183.53  67.07  32.55  55.29
# 2015-12-30   17.05   52.30  182.01  66.59  32.23  54.89
# 2015-12-31   16.83   51.75  180.23  66.03  31.81  54.36
#
# [2517 rows x 6 columns]

# %%
bank_stocks.xs(key='Close',level=1,axis=1).corr()
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971514  0.550950  0.103896  0.944219  0.008567
# C            0.971514  1.000000  0.434171  0.003540  0.933605 -0.068441
# GS           0.550950  0.434171  1.000000  0.685280  0.683834  0.499901
# JPM          0.103896  0.003540  0.685280  1.000000  0.250441  0.940279
# MS           0.944219  0.933605  0.683834  0.250441  1.000000  0.131864
# WFC          0.008567 -0.068441  0.499901  0.940279  0.131864  1.000000

# %%
sns.heatmap(bank_stocks.xs(key='Close',level=1,axis=1).corr(),cmap='GnBu')

# %%
sns.clustermap(bank_stocks.xs(key='Close',level=1,axis=1).corr(),cmap='GnBu',annot=True)

# %% [markdown]
# # Part 2 (Optional) Technical analysis capabilities in plotly and cufflink
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %%
close_corr = bank_stocks.xs(key='Close',level=1,axis=1).corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="1738499e-1fea-4475-9640-322fcb452612" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
#candlestick plot
bank_stocks['BAC'].drop(columns='Volume').loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>                            <div id="939b8be1-1b73-436c-9e96-8fe7d4a426ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
#Simple  moving Averages
bank_stocks['MS'].drop(columns='Volume').loc['2015-01-01':'2016-01-01']
# Out:
# Stock Info   Open   High    Low  Close
# Date
# 2015-01-02  39.05  39.15  38.25  38.71
# 2015-01-05  38.46  38.59  37.18  37.50
# 2015-01-06  37.47  37.54  36.06  36.42
# 2015-01-07  36.93  37.05  36.60  36.94
# 2015-01-08  37.29  37.76  37.29  37.49
# ...           ...    ...    ...    ...
# 2015-12-24  32.57  32.71  32.44  32.48
# 2015-12-28  32.36  32.36  31.95  32.17
# 2015-12-29  32.44  32.70  32.32  32.55
# 2015-12-30  32.50  32.64  32.20  32.23
# 2015-12-31  31.91  32.30  31.77  31.81
#
# [252 rows x 4 columns]

# %%
bank_stocks['MS'].drop(columns='Volume').loc['2015-01-01':'2016-01-01']['Close'].ta_plot(study='sma',periods=[13,21,55])
# Out:
# <div>                            <div id="e0c0ece6-ea81-413a-af16-2f9112fc0e05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
#show standard diviation of the stock price as it moves out through time
bank_stocks['BAC'].drop(columns='Volume').loc['2015-01-01':'2016-01-01']['Close'].ta_plot(study='boll')
# Out:
# <div>                            <div id="acc06f52-895b-43a8-b7fe-a390bc6f6b27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Take a time more on financial topics, and you will be glad about it **

# %% [markdown]
# # WELL DONE! ^_^
