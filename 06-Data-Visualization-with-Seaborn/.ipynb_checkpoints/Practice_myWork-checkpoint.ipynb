# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')
planets = sns.load_dataset('planets')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
diamonds['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamonds['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
plt.figure(figsize=(12,5))
sns.set_style('ticks')
sns.set_context('notebook',font_scale=1.5)
sns.distplot(diamonds['price'],bins=100,color='g')

# %%
sns.set_context("notebook")
sns.jointplot(x='depth',y='price',data=diamonds,kind='scatter',xlim=(55,57),height=10)

# %%
plt.figure(figsize=(12,5))
sns.set_context('talk')
sns.violinplot(x='cut',y='price',data=diamonds)

# %%
plt.figure(figsize=(10,5))
sns.set_context('notebook',font_scale=1.25)
sns.jointplot(x='x',y='price',data=diamonds,xlim=(7,8),ylim=(12500,13000),color='purple')

# %%
plot = sns.FacetGrid(data=diamonds,col='cut',row='clarity',xlim=(0,10000),height=8)
plot.map(sns.distplot,'price',color='r')

# %%
sns.jointplot(x='orbital_period',y='mass',data=planets,kind='hex',xlim=(0,2500),ylim=(0,5),color='orange')

# %%
sns.pairplot(planets)

# %%
sns.jointplot(x='year',y='mass',data=planets,kind='kde',color='r',xlim=(2000,2015),ylim=(-2,5))

# %%
dots = sns.load_dataset('dots')
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
plot = sns.FacetGrid(data=dots,col='align',row='choice',aspect=2)
plot.map(sns.distplot,'time')

# %%
dc = dots.corr()
dc
# Out:
#                  time  coherence  firing_rate
# time         1.000000   0.011710    -0.148515
# coherence    0.011710   1.000000    -0.127279
# firing_rate -0.148515  -0.127279     1.000000

# %%
sns.heatmap(dc,cmap='BuPu')

# %%
di = diamonds.pivot_table(index='clarity',columns='cut',values='price')
di
# Out:
# cut             Fair         Good        Ideal      Premium    Very Good
# clarity
# I1       3703.533333  3596.635417  4335.726027  3947.331707  4078.226190
# IF       1912.333333  4098.323944  2272.913366  3856.143478  4396.216418
# SI1      4208.279412  3689.533333  3752.118169  4455.269371  3932.391049
# SI2      5173.916309  4580.260870  4755.952656  5545.936928  4988.688095
# VS1      4165.141176  3801.445988  3489.744497  4485.462041  3805.353239
# VS2      4174.724138  4262.236196  3284.550385  4550.331248  4215.759552
# VVS1     3871.352941  2254.774194  2468.129458  2831.206169  2459.441065
# VVS2     3349.768116  3079.108392  3250.290100  3795.122989  3037.765182

# %%
sns.heatmap(di,cmap='YlGnBu')

# %%
sns.heatmap()

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
